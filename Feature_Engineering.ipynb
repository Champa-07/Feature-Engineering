# %% [markdown]
# <a href="https://colab.research.google.com/github/Champa-07/Feature-Engineering/blob/main/Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Feature Engineering- Handling the missing values

# %%
import pandas as pd

# %%
df=pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df['Embarked'].isnull()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ae54c9b55e6f> in <module>()
# ----> 1 df[df['Embarked'].isnull()]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ###### Above is the example of Missing Completely at Random

# %% [markdown]
# # Missing data not at Random:Systamic missing values
# There is absolutely some relationship between the data missing and any other values, observed or missing within the dataset

# %%
##Creating new column by replacing cabin null values with 1 n 0

# %%
import numpy as np
df['Cabin_null']=np.where(df['Cabin'].isnull(),1,0)

##find the percentage of null values
df['Cabin_null'].mean()
# Out:
# 0.7710437710437711

# %%
df.groupby(['Survived'])['Cabin_null'].mean()
# Out:
# Survived
# 0    0.876138
# 1    0.602339
# Name: Cabin_null, dtype: float64

# %% [markdown]
# The Percentage of Survived people whose data is missing is 0.6
#
# The Percentage of Non Survived People whose data is missing is 0.8

# %% [markdown]
# # Missing At Random
# Men hide their salary
#
# Women hide their age

# %% [markdown]
# ## All Techniques to handle the missing values
#
# 1.Mean/Median/Mode replacement
# 2.Random sample Imputation
# 3.Capturing Nan values with a new feature
# 4.End of Distribution Imputation
# 5.Arbitary Imputation
# 6.Freuent category imputation

# %% [markdown]
# #### Mean/Median/Mode Replacement
#
# when should we apply?
#
# It has the assumption that the data are missing completely at Random
# We solev this by Replacing the Nan with The most freuents occurance of variables

# %%
df=pd.read_csv('titanic.csv',usecols=['Age','Fare','Survived'])

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean()
# Out:
# Survived    0.000000
# Age         0.198653
# Fare        0.000000
# dtype: float64

# %%
def impute_nan(df,variable,median):
    df[variable+"_median"]=df[variable].fillna(median)

# %%
median=df.Age.median()
median
# Out:
# 28.0

# %%
impute_nan(df,'Age',median)
df.head()
# Out:
#    Survived   Age     Fare  Age_median
# 0         0  22.0   7.2500        22.0
# 1         1  38.0  71.2833        38.0
# 2         1  26.0   7.9250        26.0
# 3         1  35.0  53.1000        35.0
# 4         0  35.0   8.0500        35.0

# %%
print(df['Age'].std())
print(df['Age_median'].std())
# Out:
# 14.526497332334044
# 13.019696550973194

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
df['Age'].plot(kind='kde',ax=ax)
df['Age_median'].plot(kind='kde',ax=ax,color='red')
lines,labels=ax.get_legend_handles_labels()
ax.legend(lines,labels,loc='best')
